# %%
import random

# %%
random.randint(1,100)
# Out:
# 35

# %%
guess = random.randint(1,100)

user=int(input("Guess the number"))

while user != guess:
    if user < guess:
        print("Guess higher")
    else:print("Guess Lower")
    user=int(input("Guess the number"))
print("correct")
# Out:
# Guess the number 12
# Guess higher
# Guess the number 50
# Guess Lower
# Guess the number 40
# Guess Lower
# Guess the number 30
# Guess higher
# Guess the number 35
# Guess higher
# Guess the number 36
# Guess higher
# Guess the number 38
# correct

# %%
guess = random.randint(1,100)

user=int(input("Guess the number"))

while user != guess:
    if user < guess:
        print("Guess higher")
    else:print("Guess Lower")
    user=int(input("Guess the number"))
print("correct")
