# %% [markdown]
# # Variable

# %%
# in c int a= 5

# %%
name='Vishal'

# %%
print(name)
# Out:
# Vishal

# %%
name = Vishal
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 name = Vishal
#
# NameError: name 'Vishal' is not defined

# %%
name= 'Hello World'
print(name)
# Out:
# Hello World

# %%
# No varibale decration in Python

# %%
# Dynamic Typing = Pyhton --> PHP 
# Static Typing

# %%
# Dynamic Binding means a variable can store multiple values 
print(name)
# Out:
# Hello World

# %%
name=12
print(name)
# Out:
# 12

# %%
# Static Binding which is in the c language

# %% [markdown]
# # Special Syntax

# %%
a=5;b=10;c=20
print(a)
print(b)
print(c)
# Out:
# 5
# 10
# 20

# %%
a,b,c=4,5,6
print(a)
print(b)
print(c)
# Out:
# 4
# 5
# 6

# %%
a=b=c=6
print(a)
print(b)
print(c)
# Out:
# 6
# 6
# 6
