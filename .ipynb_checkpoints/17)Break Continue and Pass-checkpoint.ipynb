# %% [markdown]
# # Break

# %%
for i in range(1,11):
    if i==5:
        break
    print('i')
# Out:
# i
# i
# i
# i

# %% [markdown]
# # Continue

# %%
for l in range(1,11):
    if l==5:
        continue
    print(l)
# Out:
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9
# 10

# %% [markdown]
# # Pass

# %%
for i in range(1,11):
    pass
