# %%
# correct email= vishalsinghomr@gmail.com
# correct password = 123

# %%
email = input("Enter the Email")
password= int(input("Enter the Password"))

if email == "vishalsinghomr@gmail.com" and password== 123:
    print("Welcome")
elif email == "vishalsinghomr@gmail.com" and password!=123:
    print("Incorect Pass")
    int(input("Try again Password"))
else:print("Incorrect")
# Out:
# Enter the Email vishalsinghomr@gmail.com
# Enter the Password 54
# Incorect Pass
# Try again Password 67

# %%
bin(1)
# Out:
# '0b1'

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(*args, sep=' ', end='\n', file=None, flush=False)
#     Prints the values to a stream, or to sys.stdout by default.
#
#     sep
#       string inserted between values, default a space.
#     end
#       string appended after the last value, default a newline.
#     file
#       a file-like object (stream); defaults to the current sys.stdout.
#     flush
#       whether to forcibly flush the stream.

# %%
import time

# %%
time.time()
# Out:
# 1757324475.3506217

# %%
time.ctime()
# Out:
# 'Mon Sep  8 15:12:04 2025'

# %%
print('Hello')
time.sleep(5)
print('World')
# Out:
# Hello
# World

# %%
import os

# %%
os.getcwd()
# Out:
# 'E:\\PY File\\Python'

# %%
os.listdir()
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  '01)Print Function.ipynb',
#  '02)DataTypes.ipynb',
#  '03)Comment.ipynb',
#  '04)Variables.ipynb',
#  '05)Keyword&Identifierss.ipynb',
#  '06)taking-user-input.ipynb',
#  '07)-Type-Conversion.ipynb',
#  '08)Literals.ipynb',
#  '09)Operators.ipynb',
#  '10)Decision-control.ipynb',
#  '11)Operators.ipynb',
#  '12)Indentation.ipynb',
#  '13)While_Loops.ipynb',
#  '14)For_Loop.ipynb',
#  '15)For_Loop.ipynb',
#  '16)Guess_Game.ipynb',
#  '17)Break Continue and Pass.ipynb',
#  '18)Built-in-funcs.ipynb',
#  '19)built-in-modules.ipynb',
#  'Untitled.ipynb']

# %%
a=("It's my birthday")

# %%
print(a[2])
# Out:
# '
