# %%
print("Hello World")
# Out:
# Hello World

# %%
print(5)
# Out:
# 5

# %%
print(5.7)
# Out:
# 5.7

# %%
print(True)
# Out:
# True

# %%
print("India",'Canada','Austriala','Uae')
# Out:
# India Canada Austriala Uae

# %%
print('India',2,4.5)
# Out:
# India 2 4.5

# %%
print("India",'Canada','Austriala','Uae',sep='/')
# Out:
# India/Canada/Austriala/Uae

# %%
print("India",'Canada','Austriala','Uae',sep='-')
# Out:
# India-Canada-Austriala-Uae

# %%
print('Hello')
print('World')
# Out:
# Hello
# World

# %%
print('Hello',end=' ')
print('World')
# Out:
# Hello World
