# %% [markdown]
# # Tyoe Conversion

# %% [markdown]
# ## Types
# #### Implicit
# #### Explicit

# %%
## Implicit

# %%
4+4.5
# Out:
# 8.5

# %%
4.4+45j
# Out:
# (4.4+45j)

# %%
# Exokicit

# %%
# int
int(4.5)
# Out:
# 4

# %%
float(4)
# Out:
# 4.0

# %%
str(12)
# Out:
# '12'

# %%
bool(1)
# Out:
# True

# %%
complex(12)
# Out:
# (12+0j)

# %%
list('hello')
# Out:
# ['h', 'e', 'l', 'l', 'o']
